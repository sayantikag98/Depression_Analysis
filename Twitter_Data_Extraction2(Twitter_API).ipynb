# %%
import tweepy
from tweepy import OAuthHandler
 
# Twittter App Credentials
consumer_key = "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"
consumer_secret = "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"
access_token = "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"
access_token_secret = "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"
 
# Calling API
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %% [markdown]
# # RANDOM TWEETS

# %%
# Here keywords for extracting random tweets has been used
import pandas as pd
keyword1 = ["great","life","feeling","win","live","best","cool","hope","know","lol","music","school","college","fun","today","want","time","back","call","look","first","please","everyone","amazing","summer","rain","winter","wait","cause","coming","even","odd","maybe","head","big","small","soon","later","run","lot","show","least","most","yeah","way","hi","hello"]
 
# Fetching tweets using twitter API cons
# maximum count would be 100 default is 15
## No tweets can be extracted older than a week 
## historical tweets can't be extracted
tweets1=[]
for i in keyword1:
    tweets1.append(tweepy.Cursor(api.search,q=i, lang='en', exclude='retweets',tweet_mode="extended", until='2020-08-18', result_type='mixed',geocode="21.146,79.088,1650km").items())
    
id1=[]
datetime=[]
text=[]
username=[]
userloc=[]

for i in range(len(tweets1)):
    for info in tweets1[i]:
        id1.append(info.id)
        datetime.append(info.created_at)
        text.append(info.full_text)
        username.append(info.user.screen_name)
        userloc.append(info.user.location)
        
    
    
        

df2=pd.DataFrame()
df2['tweet_ID']=id1
df2['user_Name']=username
df2['timeline']=datetime
df2['location']=userloc
df2['tweet_Text']=text


    
df2
# Out:
#                tweet_ID        user_Name            timeline  \
# 0   1295510667718352897  Sanathkanakama1 2020-08-17 23:59:47
# 1   1295506444876300288           mroyme 2020-08-17 23:43:00
# 2   1295509958599929858    Rajiv15473704 2020-08-17 23:56:58
# 3   1295510458242420737    cordonblues09 2020-08-17 23:58:57
# 4   1295509434433708032  MnooriAlRumaihi 2020-08-17 23:54:53
# 5   1295506351205093377         bassanup 2020-08-17 23:42:38
# 6   1295506794014486528     urbanmorgans 2020-08-17 23:44:23
# 7   1295509860671348736      Ashik_jhs68 2020-08-17 23:56:34
# 8   1295508307747074055     pradeepsri72 2020-08-17 23:50:24
# 9   1295506993008934912       JJ72493106 2020-08-17 23:45:11
# 10  1295506211367002112     postnewyears 2020-08-17 23:42:04
# 11  1295510375111237633   Digital_Muscle 2020-08-17 23:58:37
# 12  1295509056069591041       CharubalaB 2020-08-17 23:53:23
# 13  1295508542321917952    maythinzartun 2020-08-17 23:51:20
# ...

# %% [markdown]
# # DEPRESSED TWEETS

# %%
# Here keywords which is mostly used by depressed people has been used

keyword = ["depression","depressed","anxiety","overwhelmed","exhausted","distressed","anxious","tired","low","discouraged","desperate","demotivated","insomnia","cry","nervous","worried","lonely","sad","empty"]
 

tweets=[]
for i in keyword:
    tweets.append(tweepy.Cursor(api.search,q=i, lang='en', exclude='retweets',tweet_mode="extended", until='2020-08-18', result_type='mixed',geocode="21.146,79.088,1650km").items())
    
id1=[]
datetime=[]
text=[]
username=[]
userloc=[]
retweet=[]
favourite=[]

for i in range(len(tweets)):
    for info in tweets[i]:
        id1.append(info.id)
        datetime.append(info.created_at)
        text.append(info.full_text)
        username.append(info.user.screen_name)
        userloc.append(info.user.location)
    
        
        
        
        
    
    
        

df1=pd.DataFrame()
df1['tweet_ID']=id1
df1['user_Name']=username
df1['timeline']=datetime
df1['location']=userloc
df1['tweet_Text']=text


    
df1
# Out:
#                tweet_ID        user_Name            timeline  \
# 0   1295506211367002112     postnewyears 2020-08-17 23:42:04
# 1   1295510458242420737    cordonblues09 2020-08-17 23:58:57
# 2   1295441681433669642          urmyi_m 2020-08-17 19:25:39
# 3   1295424295800381441     RhythaHejaze 2020-08-17 18:16:34
# 4   1295396297260896258      Y_Mashhrawi 2020-08-17 16:25:19
# 5   1295395503614488577   dialecticsumit 2020-08-17 16:22:10
# 6   1295379309163470848  MaheshP69110628 2020-08-17 15:17:48
# 7   1295374929475510277         kwangg28 2020-08-17 15:00:24
# 8   1295344702254796801    raghu_madgula 2020-08-17 13:00:18
# 9   1295322171707756550      HyattRaipur 2020-08-17 11:30:46
# 10  1295472415271788550       AAlHamoud7 2020-08-17 21:27:47
# 11  1295456598286987264     anupam_hazra 2020-08-17 20:24:56
# 12  1295422460326625280   chota_engineer 2020-08-17 18:09:16
# 13  1295417885074964482           nlasya 2020-08-17 17:51:06
# ...

# %%
usernameList_Depressed=list(df1['user_Name'])
 
## for extracting the usernames from the depressed tweets dataframe 
tweets=[]
for i in usernameList_Depressed:
    tweets.append(api.user_timeline(screen_name=i, lang='en', exclude='retweets',tweet_mode="extended", until='2020-08-18', result_type='mixed',geocode="21.146,79.088,1650km"))
    
    
    
    
tmp=[]  

# creation of an array of tweet information: username,  
# tweet id, date/time, text 
for tweet in tweets:
    for t in tweet:
        tmp.append(t)
        
        
print(len(tmp))
# Out:
# 549

# %%
usernameList_Random=list(df2['user_Name'])

## for extracting the usernames from the random tweets dataframe 
tweets=[]
for i in usernameList_Random:
    tweets.append(api.user_timeline(screen_name=i, lang='en', exclude='retweets',tweet_mode="extended", until='2020-08-18', result_type='mixed',geocode="21.146,79.088,1650km"))
    

    
tmp=[]  

# creation of an array of tweet information: username,  
# tweet id, date/time, text 
for tweet in tweets:
    for t in tweet:
        tmp.append(t)
        
        
print(len(tmp))
# Out:
# 760

# %%
print(usernameList_Depressed) ### username from depressed tweets dataset
# Out:
# ['postnewyears', 'cordonblues09', 'urmyi_m', 'RhythaHejaze', 'Y_Mashhrawi', 'dialecticsumit', 'MaheshP69110628', 'kwangg28', 'raghu_madgula', 'HyattRaipur', 'AAlHamoud7', 'anupam_hazra', 'chota_engineer', 'nlasya', 'rameshlaus', 'mumbhaikarsays', 'AzhanAnsari20', 'AdityadixitNsui', 'AmberTiwari12', 'vidhiJa70233437', 'PrasenjeetKuma6', 'jimmy_hofa', 'MasabaG', 'tmj_SAU_manuf', 'EbrahimMattar1', 'vsarv_', 'vsarv_', 'a3007_']

# %%
import numpy as np
print(np.unique(usernameList_Random))  ### username from random tweets dataset
# Out:
# ['Ashik_jhs68' 'AyeshaAraien' 'CharubalaB' 'Digital_Muscle' 'FordLovers3'
#  'HarpalCheemaMLA' 'JJ72493106' 'MnooriAlRumaihi' 'Rajiv15473704'
#  'Sanathkanakama1' 'aishabellucci' 'arpan84' 'babycandy96xxx' 'bassanup'
#  'cb89be1fc9ca477' 'cordonblues09' 'dr_rs84' 'iamdebashis_'
#  'ipkinderpreet' 'maythinzartun' 'mroyme' 'navmathur' 'postnewyears'
#  'pradeepsri72' 'rohenw123' 'sameerAljama' 'shsayed2' 'urbanmorgans']
