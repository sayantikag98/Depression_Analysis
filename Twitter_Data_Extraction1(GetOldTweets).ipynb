# %%
## Importing the libraries
import pandas as pd
import glob, os 

## Tweets that has been extracted from 16-06-20 to 15-07-20 within the Indian subcontinent related to words 
## "depression","depressed","anxiety","overwhelmed","exhausted","distressed","anxious","tired","low","discouraged","desperate","demotivated","insomnia","cry","nervous","worried","lonely","sad","empty" 
## that is used mostly by people in depression 

## At first the timeline of the tweets to be extracted was taken as one month mid-June to mid-July but later it was extended to 10 years from 2010 to 2020
path = r'C:\Users\Sayantika Ghosh\topTweets'
df = pd.concat(map(pd.read_csv, glob.glob(os.path.join(path, "*.csv"))),ignore_index=True)
df['date']=pd.to_datetime(df['date'])
df
# Out:
#                     date         username               to  replies  retweets  \
# 0    2020-07-12 08:26:44         AnaRimo6              NaN        5        14
# 1    2020-07-12 05:54:02          0_0eth0              NaN        1        22
# 2    2020-07-11 20:38:33     JairajSinghR              NaN        6        16
# 3    2020-07-11 16:58:29      PrasadKarwa              NaN        4        10
# 4    2020-07-10 19:09:21        Jamana_89              NaN        2        26
# ...                  ...              ...              ...      ...       ...
# 1106 2020-06-16 05:16:13   hironmukherjee         TimesNow        0         0
# 1107 2020-06-16 04:36:00          i_ronyk        D_D_great        0         0
# 1108 2020-06-16 04:21:34     SatheeshGodi           E28549        0         0
# 1109 2020-06-16 00:30:43       djpaul1982  sardesairajdeep        1         1
# 1110 2020-06-16 00:16:58  The_PattayaNews              NaN        0         0
#
# ...

# %%
df['date']
# Out:
# 0      2020-07-12 08:26:44
# 1      2020-07-12 05:54:02
# 2      2020-07-11 20:38:33
# 3      2020-07-11 16:58:29
# 4      2020-07-10 19:09:21
#                ...
# 1106   2020-06-16 05:16:13
# 1107   2020-06-16 04:36:00
# 1108   2020-06-16 04:21:34
# 1109   2020-06-16 00:30:43
# 1110   2020-06-16 00:16:58
# Name: date, Length: 1111, dtype: datetime64[ns]

# %%
## Tweets that has been extracted from 01-06-2010 to 15-08-2020 within the Indian subcontinent using the keyword search
path = r'C:\Users\Sayantika Ghosh\top_ten'
df1 = pd.concat(map(pd.read_csv, glob.glob(os.path.join(path, "*.csv"))),ignore_index=True)
df1['date']=pd.to_datetime(df1['date'])
df1
# Out:
#                      date         username               to  replies  \
# 0     2020-08-14 22:14:22         www_wtf_              NaN        0
# 1     2020-08-14 14:30:00     SamsungIndia              NaN       99
# 2     2020-08-14 19:42:06       HusynSajid              NaN        2
# 3     2020-08-14 10:05:29  rosehipsdontlie      serenescure        2
# 4     2020-08-14 07:38:09  TheGrumpyDoctor              NaN        6
# ...                   ...              ...              ...      ...
# 17607 2010-09-24 08:44:06           vinitg              NaN        0
# 17608 2010-09-19 13:54:53           BeYess              NaN        0
# 17609 2010-09-16 06:15:58            kjohn       JackPrinya        0
# 17610 2010-09-15 13:54:21         aktiwary  stevelitchfield        0
# 17611 2010-09-12 06:35:38    prashanthmano              NaN        0
#
#        retweets  favorites                                               text  \
# ...

# %%
print(df.shape)
print(df1.shape)
# Out:
# (1111, 12)
# (17612, 12)

# %%
## to plot the curve of retweets over ten years
import matplotlib.pyplot as plt
plt.figure(figsize=(50,50))
plt.plot(df1['date'],df1['retweets'])
plt.show()

# %%
df1['retweets'].max()
# Out:
# 27951

# %%
df1['retweets'].min()
# Out:
# 0

# %%
## to plot the curve of favorites over ten years
plt.figure(figsize=(50,50))
plt.plot(df1['date'],df1['favorites'])
plt.show()

# %%
## to check for the repetition in the username
import numpy as np
arr=np.unique(df1.username,return_index=True,return_inverse=True,return_counts=True)

# %%
type(arr)
# Out:
# tuple

# %%
## gives the username
arr[0]
# Out:
# array(['000Mind', '007Prashsharma', '05sarah_', ..., 'zunairashabbir_',
#        'zunshine14', 'zyptical'], dtype=object)

# %%
type(arr[3]) ## gives the count of the repetition
# Out:
# numpy.ndarray

# %%
arr[3]>30
indexList=[]
for i,val in enumerate(arr[3]):
    if (val>11):
        indexList.append(i)
        
print(indexList)       
print(len(indexList))  ## index of the repeats
# Out:
# [159, 160, 253, 256, 423, 457, 469, 495, 594, 1156, 1266, 1305, 1339, 1388, 1399, 1400, 1602, 1684, 1811, 1944, 1959, 2099, 2137, 2182, 2233, 2294, 2373, 2399, 2449, 2514, 2531, 2626, 2733, 2798, 2964, 3040, 3223, 3365, 3395, 3404, 3500, 3727, 3780, 3784, 3956, 3997, 4019, 4061, 4137, 4140, 4235, 4259, 4356, 4387, 4432, 4665, 4681, 4801, 4895, 5101, 5112, 5165, 5314, 5334, 5374, 5507, 5526, 5700, 5728, 5850, 6001, 6002, 6064, 6234, 6255, 6347, 6511, 6535, 6923, 7120, 7190, 7218, 7270, 7308, 7357, 7563, 7637, 7834, 7837, 8048, 8301, 8322, 8392, 8397, 8486, 8540, 8960, 9006, 9031, 9067, 9114, 9249, 9277, 9477, 9540, 9570, 9716, 9802, 9926, 10323]
# 110

# %%
user_name=[]
for i in indexList:
    user_name.append(arr[0][i])
print(user_name)
print(len(user_name)) ## username of the repeats
# Out:
# ['Aabhas24', 'AabidMagami', 'AdityaMenon22', 'AdityaRajKaul', 'AmirMateen2', 'AnandGu29284411', 'Andrew007Uk', 'AnimaSonkar', 'Arun2981', 'DalrympleWill', 'DineshGhodke', 'DrAMSinghvi', 'DrVikasPadha', 'EevaPaavilainen', 'ElizaMajumder', 'Elizatweetz', 'GamesRedDeer', 'GuftarAhmedCh', 'HasibaAmin', 'I_amkrish007', 'IamOnir', 'Iyervval', 'JalalQazi', 'JhaSanjay', 'JournoAshutosh', 'KVishReddy', 'KazmiWajahat', 'Khalefornia', 'KishoreRF', 'KyuniesBoyMikey', 'LaLaMuneer33', 'LonelySoulBckup', 'Madhusudan222', 'MandeepBajwa', 'Miss_Ankiita', 'MrinalPande1', 'NileshShah68', 'PairsonnalitesA', 'ParagRudani', 'ParshKi_Neha', 'PrasadKarwa', 'RatanSharda55', 'RiaRevealed', 'RichardBarrow', 'SagarDyola', 'Salonnnniiii', 'SamsungIndia', 'Sanjay_Dixit', 'SeharKamran', 'SenatorMashhadi', 'Shiffa_ZY', 'ShivaniPatel23', 'SohaTazz', 'SriLankaTweet', 'Suhelseth', 'TheShuchiSingh', 'The_Sunita', 'Usmanalisayyed', 'VishweshwarBhat', '_Humourless', '_MaryamRizvi_', '_hxnd_', 'adeel_azhar', 'advmonikaaro
# ...

# %% [markdown]
# # DEPRESSED TWEET DATASET FROM GET OLD TWEETS

# %%
## Top tweets that has been extracted from 01-06-2010 to 15-08-2020 within the Indian subcontinent using the username search
path = r'C:\Users\Sayantika Ghosh\user_depressed1'
df2 = pd.concat(map(pd.read_csv, glob.glob(os.path.join(path, "*.csv"))),ignore_index=True)
df2['date']=pd.to_datetime(df2['date'])
df2
# Out:
#                       date   username             to  replies  retweets  \
# 0      2020-08-14 12:42:55   Aabhas24      r_bhaduri       27       149
# 1      2020-08-14 09:12:18   Aabhas24      r_bhaduri        6        58
# 2      2020-08-13 18:15:06   Aabhas24      r_bhaduri       13        95
# 3      2020-08-13 18:08:05   Aabhas24      r_bhaduri        6       110
# 4      2020-08-13 15:43:21   Aabhas24  NitinRaut_INC       13       120
# ...                    ...        ...            ...      ...       ...
# 149385 2015-05-29 17:52:40  yessirtns            NaN        0         0
# 149386 2015-05-29 17:29:43  yessirtns            NaN        0         1
# 149387 2015-05-29 17:02:17  yessirtns            NaN        0         0
# 149388 2015-05-29 16:26:19  yessirtns            NaN        0         0
# 149389 2015-05-29 16:20:49  yessirtns            NaN        0         0
#
#         favorites                                               text  geo  \
# ...

# %% [markdown]
# # RANDOM TWEET FROM TWITTER API

# %%
## Top tweets that has been extracted from 01-06-2010 to 15-08-2020 within the Indian subcontinent using the username search
path = r'C:\Users\Sayantika Ghosh\user_random'
df3 = pd.concat(map(pd.read_csv, glob.glob(os.path.join(path, "*.csv"))),ignore_index=True)
df3['date']=pd.to_datetime(df3['date'])
df3
# Out:
#                     date         username               to  replies  retweets  \
# 0    2020-08-10 18:00:40  Sanathkanakama1    BeerBicepsGuy        0         0
# 1    2020-08-10 17:54:34  Sanathkanakama1              NaN        0         0
# 2    2020-08-10 17:48:22  Sanathkanakama1   LukeCoutinho17        0         0
# 3    2020-08-10 17:39:40  Sanathkanakama1              NaN        0         0
# 4    2020-08-09 18:47:26  Sanathkanakama1  MasculineTheory        0         0
# ...                  ...              ...              ...      ...       ...
# 6086 2020-02-07 06:07:14     pradeepsri72  sardesairajdeep        0         0
# 6087 2020-02-06 10:41:17     pradeepsri72      nailainayat        0         0
# 6088 2020-02-06 10:40:28     pradeepsri72      nailainayat        0         0
# 6089 2020-02-05 02:28:52     pradeepsri72        ShivAroor        0         0
# 6090 2020-02-04 15:14:13     pradeepsri72      nailainayat        0         0
#
# ...

# %% [markdown]
# # DEPRESSED TWEETS FROM TWITTER API

# %%
## Top tweets that has been extracted from 01-06-2010 to 15-08-2020 within the Indian subcontinent using the username search
path = r'C:\Users\Sayantika Ghosh\user_depressed'
df4 = pd.concat(map(pd.read_csv, glob.glob(os.path.join(path, "*.csv"))),ignore_index=True)
df4['date']=pd.to_datetime(df4['date'])
df4
# Out:
#                     date       username               to  replies  retweets  \
# 0    2020-02-12 09:29:03    Y_Mashhrawi              NaN        0         1
# 1    2019-10-22 18:52:34    Y_Mashhrawi              NaN        1         0
# 2    2019-09-26 20:31:36    Y_Mashhrawi              NaN        0         0
# 3    2020-08-06 08:10:18    HyattRaipur              NaN        0         0
# 4    2020-07-29 04:12:55    HyattRaipur              NaN        0         0
# ...                  ...            ...              ...      ...       ...
# 9917 2020-08-11 11:48:40  raghu_madgula     SaketGokhale        0         0
# 9918 2020-08-11 11:39:32  raghu_madgula   ivivek_nambiar        1         1
# 9919 2020-08-11 11:30:15  raghu_madgula   GURU_Naarayana        2         0
# 9920 2020-08-11 11:09:10  raghu_madgula     Aakar__Patel        1         4
# 9921 2020-08-11 11:04:14  raghu_madgula  queen_pratiksha        0         0
#
# ...

# %% [markdown]
# # RANDOM TWEETS FROM GET OLD TWEETS

# %%
## Top tweets that has been extracted from 01-06-2010 to 15-08-2020 within the Indian subcontinent using the keyword search
path = r'C:\Users\Sayantika Ghosh\user_random1'
df5 = pd.concat(map(pd.read_csv, glob.glob(os.path.join(path, "*.csv"))),ignore_index=True)
df5['date']=pd.to_datetime(df5['date'])
df5
# Out:
#                       date        username           to  replies  retweets  \
# 0      2020-08-14 23:07:57  DesktopOKnaKub          NaN        0        49
# 1      2020-08-14 12:37:49      airtelbank          NaN       13       105
# 2      2020-08-14 10:10:02       JalalQazi          NaN      140       451
# 3      2020-08-14 08:09:45             ANI          NaN      395       860
# 4      2020-08-14 05:28:36    yasmin2wish_          NaN        1        13
# ...                    ...             ...          ...      ...       ...
# 128471 2010-09-15 01:58:37          ling75    rioferdy5        0         0
# 128472 2010-09-14 22:15:17     prasutweets          NaN        0         0
# 128473 2010-09-14 16:59:44       GDsouza95          NaN        0         0
# 128474 2010-09-14 03:39:52         snagpal     adgujral        0         0
# 128475 2010-09-11 03:25:41            psl_  TalosKnight        0         0
#
# ...

# %%
arr=np.unique(df5.username,return_counts=True)
arr
# Out:
# (array(['0001Cp', '0001Nayra1', '0003CutiePi', ..., 'zxyxd_h',
#         'zzbarafwala', 'zznebenzz'], dtype=object),
#  array([2, 1, 1, ..., 1, 1, 1], dtype=int64))

# %%
indexList=[]
for i,val in enumerate(arr[1]):
    if (val>34):
        indexList.append(i)
        
print(indexList)       
print(len(indexList))  ## index of the repeats
# Out:
# [300, 438, 471, 505, 627, 629, 778, 871, 1005, 1168, 1243, 1262, 1411, 1624, 1661, 1682, 1700, 1831, 1903, 1917, 2211, 2294, 2371, 2392, 2420, 2598, 2629, 2800, 2992, 3039, 3119, 3195, 3264, 3384, 3875, 3987, 4026, 4072, 4453, 4662, 5156, 5213, 5315, 5441, 5524, 5618, 5645, 5661, 5693, 5695, 5770, 5870, 6114, 6145, 6348, 6406, 6442, 6813, 7091, 7114, 7167, 7211, 7234, 7504, 7561, 7719, 7729, 7773, 7988, 8119, 8217, 8246, 8425, 8619, 8694, 8891, 8925, 9102, 9104, 9389, 9402, 9490, 9513, 9627, 9636, 9652, 9654, 9697, 9806, 9843, 9882, 9935, 9970, 10000, 10015, 10290, 10445, 10640, 10676, 10735, 10821, 10901, 11286, 11457, 11586, 11702, 11929, 12035, 12054, 12130, 12221, 12481, 12595, 12645, 12792, 12799, 12821, 12890, 13234, 13478, 13543, 13572, 13720, 13765, 14007, 14081, 14136, 14204, 14261, 14453, 14827, 14913, 14919, 15046, 15192, 15204, 15359, 15551, 15671, 15958, 16130, 16254, 16266, 16293, 16294, 16295, 16313, 16427, 16631, 16722, 16891, 17018, 17089, 17478, 17622, 17633, 17666,
# ...

# %%
user_name=[]
for i in indexList:
    user_name.append(arr[0][i])
print(user_name)
print(len(user_name)) ## username of the repeats
# Out:
# ['74ceff6b903445b', 'AFUZZ', 'AKRITIMUSIC', 'AM_Tanusree', 'Aabhas24', 'AabidMagami', 'AbdullahDayo', 'AbijitG', 'AdityaRajKaul', 'Aifssy', 'Ajithpandi', 'AkasaSing', 'AlexInAir', 'AmberRShamsi', 'AmirMateen2', 'AmitHPanchal', 'Amit_Jeswani1', 'Andrew007Uk', 'AnilKapoor', 'AnimaSonkar', 'ArmaanMalik22', 'Arun2981', 'Ash_Stewart_', 'AshishSinghLIVE', 'AshokMittal77', 'AvdheshanandG', 'Awan26M', 'BMTheEquityDesk', 'BansalRaman944', 'BasitSpeaks', 'BeingChatterjee', 'Benny_Dayal', 'Bhavna__B', 'BirdinginChina', 'CarolineNingsh2', 'Chandrakbose', 'CharuPragya', 'ChennaiRains', 'CynthiaDRitchie', 'DalrympleWill', 'DineshGhodke', 'DivyaMaben', 'DrAMSinghvi', 'DrVikasPadha', 'DuchessT_', 'Ebenmugeez1', 'EevaPaavilainen', 'EjazGujjar55', 'ElizaMajumder', 'Elizatweetz', 'EngineeredTags', 'EvolveLeadLove', 'Fayzth', 'Fereeha', 'GERinPAK4youth', 'GabbbarSingh', 'GamesRedDeer', 'GuftarAhmedCh', 'HarbirSinghSuri', 'HarishMega', 'HarshdeepKaur', 'HasibaAmin', 'HavaldarShinde', 'Hungama_com', 'IAmS
# ...

# %%
## Top tweets that has been extracted from 01-06-2010 to 15-08-2020 within the Indian subcontinent using the username search
path = r'C:\Users\Sayantika Ghosh\user_r1'
df6 = pd.concat(map(pd.read_csv, glob.glob(os.path.join(path, "*.csv"))),ignore_index=True)
df6['date']=pd.to_datetime(df6['date'])
df6
# Out:
#                       date         username   to  replies  retweets  \
# 0      2020-08-11 03:34:10  74ceff6b903445b  NaN       14       125
# 1      2020-07-27 13:36:37  74ceff6b903445b  NaN       12        93
# 2      2019-06-22 16:17:24  74ceff6b903445b  NaN       11        84
# 3      2019-03-27 04:33:55  74ceff6b903445b  NaN        4        95
# 4      2019-03-24 08:01:44  74ceff6b903445b  NaN        7        97
# ...                    ...              ...  ...      ...       ...
# 134533 2014-11-17 13:53:49        cuteinsan  NaN        0         0
# 134534 2014-11-01 01:19:39        cuteinsan  NaN        0         0
# 134535 2014-10-28 09:15:42        cuteinsan  NaN        0         0
# 134536 2014-10-27 17:27:17        cuteinsan  NaN        0         0
# 134537 2014-10-25 02:43:25        cuteinsan  NaN        1         0
#
#         favorites                                               text  geo  \
# 0             532  Hello dear friends. Have a beautiful Tuesday p...  NaN
# ...

# %%
## Top tweets that has been extracted from 01-06-2010 to 15-08-2020 within the Indian subcontinent using the keyword search
### many more random words related to the ongoing pandemic situation "corona","pandemic", "lockdown", etc.
path = r'C:\Users\Sayantika Ghosh\user_rand'
df7 = pd.concat(map(pd.read_csv, glob.glob(os.path.join(path, "*.csv"))),ignore_index=True)
df7['date']=pd.to_datetime(df7['date'])
df7
# Out:
#                     date         username            to  replies  retweets  \
# 0    2020-08-14 17:16:46   DrTamilisaiGuv           NaN       11        17
# 1    2020-08-14 15:43:41  Shizanisarmorai           NaN        4         8
# 2    2020-08-13 17:47:35          RudraVS  bhaiyafromup        3        27
# 3    2020-08-13 17:44:18     NileshShah68           NaN       20        90
# 4    2020-08-13 16:42:57        imshiva_b           NaN        0        13
# ...                  ...              ...           ...      ...       ...
# 5695 2011-08-04 15:09:43         iBRA_iMj           NaN        0         0
# 5696 2011-07-09 08:41:27          anuporn           NaN        0         0
# 5697 2011-06-25 04:36:02     Lostinsmiles           NaN        0         0
# 5698 2010-11-12 18:56:15    BrianSigafoos           NaN        0         0
# 5699 2010-10-07 08:23:37      praveenravi           NaN        0         0
#
# ...

# %%
arr=np.unique(df7.username,return_counts=True)
arr
# Out:
# (array(['0ffeels', '1985luckygal', '19sanatani66', ..., 'zfrmrza',
#         'zobia_raja9', 'zubun98'], dtype=object),
#  array([ 1,  1,  1, ..., 10,  1,  1], dtype=int64))

# %%
indexList=[]
for i,val in enumerate(arr[1]):
    if (val>50):
        indexList.append(i)
        
print(indexList)       
print(len(indexList))  ## index of the repeats
# Out:
# [385, 551, 827, 928, 1365, 1958, 2031]
# 7

# %%
user_name=[]
for i in indexList:
    user_name.append(arr[0][i])
print(user_name)
print(len(user_name)) ## username of the repeats
# Out:
# ['GuftarAhmedCh', 'KirenRijiju', 'RichardBarrow', 'Shamsher_IPS', 'deepak_mragwani', 'sanghaviharsh', 'sidhant']
# 7

# %%
## Top tweets that has been extracted from 01-06-2010 to 15-08-2020 within the Indian subcontinent using the username search
### many more random words related to the ongoing pandemic situation "corona","pandemic", "lockdown", etc.
path = r'C:\Users\Sayantika Ghosh\user_rand1'
df8 = pd.concat(map(pd.read_csv, glob.glob(os.path.join(path, "*.csv"))),ignore_index=True)
df8['date']=pd.to_datetime(df8['date'])
df8
# Out:
#                      date       username   to  replies  retweets  favorites  \
# 0     2020-08-14 07:46:06  GuftarAhmedCh  NaN       17        66        233
# 1     2020-08-13 16:30:58  GuftarAhmedCh  NaN        7        24        165
# 2     2020-08-12 16:15:24  GuftarAhmedCh  NaN        5        24        158
# 3     2020-08-12 05:54:43  GuftarAhmedCh  NaN       12        34        156
# 4     2020-08-11 17:31:51  GuftarAhmedCh  NaN       12        73        322
# ...                   ...            ...  ...      ...       ...        ...
# 10141 2014-09-08 10:43:16        sidhant  NaN        0         0          0
# 10142 2014-09-08 09:56:59        sidhant  NaN        0         0          0
# 10143 2014-09-08 09:51:07        sidhant  NaN        0         0          0
# 10144 2014-09-08 09:49:31        sidhant  NaN        0         0          0
# 10145 2014-09-08 09:43:13        sidhant  NaN        0         0          0
#
# ...

# %%
df8.to_csv('data_random_1.csv',index=False) ### to convert the pandas dataframe to a .csv file
